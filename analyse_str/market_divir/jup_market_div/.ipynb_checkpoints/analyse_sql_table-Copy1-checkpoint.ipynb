# %%
import pandas as pd
import sys
import psycopg2
import numpy as np

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# Connection parameters, yours will be different
param_dic = {
    "host"      : "stockschapnes.postgres.database.azure.com",
    "database"  : "postgres",
    "user"      : "chapnes",
    "password"  : "House333!",
    "port" : "5432"
}
def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1)
    print("Connection successful")
    return conn




def postgresql_to_dataframe(conn, select_query, column_names):
    """
    Tranform a SELECT query into a pandas dataframe
    """
    cursor = conn.cursor()
    try:
        cursor.execute(select_query)
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        cursor.close()
        return 1

    # Naturally we get a list of tupples
    tupples = cursor.fetchall()
    cursor.close()

    # We just need to turn it into a pandas dataframe
    df = pd.DataFrame(tupples, columns=column_names)
    return df



# Connect to the database
conn = connect(param_dic)
# column_names = ["id", "source", "datetime", "mean_temp"]
column_names = ["id", "p18_05_20_01", "p19_05_20_06", "p19_10_21_01", "p20_05_21_10", "p21_06_22_01", "p22_01", "option"]

# Execute the "SELECT *" query
# df = postgresql_to_dataframe(conn, "select * from test_100_beta_more_09", column_names)



test_100_beta_09_13 = postgresql_to_dataframe(conn, "select * from test_100_beta_09_11", column_names)
test_100_beta_11_13 = postgresql_to_dataframe(conn, "select * from test_100_beta_11_13", column_names)
test_100_beta_13_15 = postgresql_to_dataframe(conn, "select * from test_100_beta_13_15", column_names)
test_100_beta_15_2 = postgresql_to_dataframe(conn, "select * from test_100_beta_15_2", column_names)
test_100_beta_15 = postgresql_to_dataframe(conn, "select * from test_100_beta_15", column_names)
test_100_beta_more_09 = postgresql_to_dataframe(conn, "select * from test_100_beta_more_09", column_names)
test_100_more_beta_2 = postgresql_to_dataframe(conn, "select * from test_100_more_beta_2", column_names)
test_100_beta_09_2 = postgresql_to_dataframe(conn, "select * from test_100_beta_09_2", column_names)

# df
# Out:
# Connecting to the PostgreSQL database...
# Connection successful

# %%
def get_plus_results(df):
    df_more_0_pre = df[(df.p18_05_20_01 > 0)
                         & (df.p19_05_20_06 > 0)
                         & (df.p19_10_21_01 > 0)
                         & (df.p20_05_21_10 > 0)
                         & (df.p21_06_22_01 > 0)
                         & (df.p22_01 > 0)]


    df_more_0 = df_more_0_pre.copy()
    
    df_more_0['p18_05_20_01'] = df_more_0['p18_05_20_01'].astype(float)
    df_more_0['p19_05_20_06'] = df_more_0['p19_05_20_06'].astype(float)
    df_more_0['p19_10_21_01'] = df_more_0['p19_10_21_01'].astype(float)
    df_more_0['p20_05_21_10'] = df_more_0['p20_05_21_10'].astype(float)
    df_more_0['p21_06_22_01'] = df_more_0['p21_06_22_01'].astype(float)
    df_more_0['p22_01'] = df_more_0['p22_01'].astype(float)    
    
    df_more_0['Sum'] = df_more_0['p18_05_20_01'] + df_more_0['p19_05_20_06'] + df_more_0['p19_10_21_01'] + df_more_0['p20_05_21_10'] + df_more_0['p21_06_22_01'] + df_more_0['p22_01'] 
    df_more_0 = df_more_0.sort_values(by=['Sum'], ascending=False)
    return df_more_0
    
    

more_0_test_100_beta_09_13 = get_plus_results(test_100_beta_09_13)
more_0_test_100_beta_11_13 = get_plus_results(test_100_beta_11_13)
more_0_test_100_beta_13_15 = get_plus_results(test_100_beta_13_15)
more_0_test_100_beta_15_2 = get_plus_results(test_100_beta_15_2)
more_0_test_100_beta_more_09 = get_plus_results(test_100_beta_more_09)
more_0_test_100_beta_15 = get_plus_results(test_100_beta_15)
more_0_test_100_more_beta_2 = get_plus_results(test_100_more_beta_2)
more_0_test_100_beta_09_2 = get_plus_results(test_100_beta_09_2)

# %%
def get_plus_options(df):
    df_more_150 = df[(df.Sum > 50)]
    return df_more_150['option'].values


plus_test_100_beta_09_13 = get_plus_options(more_0_test_100_beta_09_13)
plus_test_100_beta_11_13 = get_plus_options(more_0_test_100_beta_11_13)
plus_test_100_beta_13_15 = get_plus_options(more_0_test_100_beta_13_15)
plus_test_100_beta_15_2 = get_plus_options(more_0_test_100_beta_15_2)
plus_test_100_beta_more_09 = get_plus_options(more_0_test_100_beta_more_09)
plus_test_100_beta_15 = get_plus_options(more_0_test_100_beta_15)
plus_test_100_more_beta_2 = get_plus_options(more_0_test_100_more_beta_2)
plus_test_100_beta_09_2 = get_plus_options(more_0_test_100_beta_09_2)

# %%
plus_test_100_beta_09_13
# Out:
# array(['gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1)'],
#       dtype=object)

# %%
more_0_test_100_beta_09_13
# Out:
#    id  p18_05_20_01  p19_05_20_06  p19_10_21_01  p20_05_21_10  p21_06_22_01    p22_01                                             option        Sum
# 4   5      4.373341     12.221861     14.793843     16.992878      0.446110  5.320780  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  54.148813
# 5   6      6.511719     13.527203     14.408773     16.820312      0.785659  1.315321  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  53.368987
# 6   7      3.558742     14.674245     20.345771      1.411276      0.008175  2.262109  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  42.260318

# %%
plus_test_100_beta_11_13
# Out:
# array(['gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 3.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 4)'],
#       dtype=object)

# %%
more_0_test_100_beta_11_13
# Out:
#    id  p18_05_20_01  p19_05_20_06  p19_10_21_01  p20_05_21_10  p21_06_22_01     p22_01                                             option        Sum
# 5   6      5.955404     16.250052     26.384479     23.137834      5.015299   7.224944  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  83.968014
# 4   5      3.323722     14.305136     26.226856     26.205233      2.246570  10.121750  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  82.429267
# 8   9      8.671424     22.882622     33.852660      3.102767      0.092060   6.129828  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  74.731360
# 6   7      7.607724     22.882622     33.742617      2.992722      0.779161   6.129829  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  74.134674

# %%
plus_test_100_beta_13_15
# Out:
# array(['gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1)'],
#       dtype=object)

# %%
more_0_test_100_beta_13_15
# Out:
#    id  p18_05_20_01  p19_05_20_06  p19_10_21_01  p20_05_21_10  p21_06_22_01     p22_01                                             option        Sum
# 4   5      3.854126     21.707176     34.308201     25.896845      1.589073  10.829457  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  98.184879
# 5   6      7.682032     25.415899     32.966545     19.751648      3.322289   7.608452  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  96.746866

# %%
plus_test_100_beta_15_2
# Out:
# array(['gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] - 2.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 2)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] - 1.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 2.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 4)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 3.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 3)'],
#       dtype=object)

# %%
more_0_test_100_beta_15_2
# Out:
#    id  p18_05_20_01  p19_05_20_06  p19_10_21_01  p20_05_21_10  p21_06_22_01     p22_01                                             option         Sum
# 0   1     28.604727     16.559690     47.826113     63.249992     16.838070   7.075955  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  180.154547
# 1   2      8.317463     34.018582     44.378364     25.613772      5.825538  22.186849  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  140.340569
# 9  10     14.571691     11.005385     39.085035     47.025808     16.591957   8.215007  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  136.494882
# 4   5      6.341582     23.672564     40.410360     36.169461      8.972329  16.238041  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  131.804337
# 3   4     10.685449     34.902016     45.229799     14.219855      4.366684  22.186848  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  131.590651
# ...

# %%
plus_test_100_beta_09_2
# Out:
# array(['gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 2)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 3.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 4)'],
#       dtype=object)

# %%
more_0_test_100_beta_09_2
# Out:
#    id  p18_05_20_01  p19_05_20_06  p19_10_21_01  p20_05_21_10  p21_06_22_01     p22_01                                             option        Sum
# 1   2      6.443192     24.619779     30.122085     16.824505      0.036863  11.586424  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  89.632848
# 4   5      4.289433     16.657370     26.213215     24.501767      2.551987   8.934737  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  83.148510
# 5   6      7.707122     18.967787     25.576292     20.501323      3.822951   6.007619  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  82.583094
# 8   9      7.655387     23.239628     32.721686      2.122239      0.870902   6.501736  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  73.111577
# 6   7      7.119051     23.239627     32.804117      2.204675      1.022227   6.501735  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  72.891432

# %%
plus_test_100_beta_15
# Out:
# array(['gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] - 2.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 2)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 2.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 4)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 3)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 3.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] - 1.5)'],
#       dtype=object)

# %%
more_0_test_100_beta_15
# Out:
#    id  p18_05_20_01  p19_05_20_06  p19_10_21_01  p20_05_21_10  p21_06_22_01     p22_01                                             option         Sum
# 0   1     18.304529     10.597650     53.629538     69.137846     17.279195   7.765948  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  176.714706
# 1   2      7.067502     40.335723     57.650829     30.495126      6.624583  22.980180  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  165.153944
# 3   4      8.726914     41.068946     58.474957     17.322608      5.502702  22.980182  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  154.076308
# 4   5      2.061954     25.571084     52.990470     43.390688     11.972951  17.843859  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  153.831006
# 5   6      6.027004     27.542665     51.237889     32.013164     12.874534  17.352493  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  147.047749
# ...

# %%
plus_test_100_more_beta_2
# Out:
# array(['gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 2)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 2.5)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 4)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 3)',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] - 2.5)'],
#       dtype=object)

# %%
more_0_test_100_more_beta_2
# Out:
#    id  p18_05_20_01  p19_05_20_06  p19_10_21_01  p20_05_21_10  p21_06_22_01     p22_01                                             option         Sum
# 1   2      4.880024     51.390708     80.877635     39.037512      8.022926  22.630911  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  206.839715
# 3   4      5.299489     51.861054     81.653995     22.752440      7.490730  22.630911  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  191.688619
# 6   7      8.126015     52.478079     81.448924      1.573934      9.916635  17.269536  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  170.813123
# 7   8      5.299476     51.861058     74.675025      7.015243      7.490739  22.630906  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  168.972448
# 0   1      0.279117      0.164091     63.785583     79.441577     18.051162   7.235840  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  168.957370

# %%
def get_minus_results(df):


    df_less_0_pre = df[(df.p18_05_20_01 < 5)
                         & (df.p19_05_20_06 < 5)
                         & (df.p19_10_21_01 < 5)
                         & (df.p20_05_21_10 < 5)
                         & (df.p21_06_22_01 < 5)
                         & (df.p22_01 < 5)]

    df_less_0 = df_less_0_pre.copy()
    
    df_less_0['Sum'] = df_less_0['p18_05_20_01'] + df_less_0['p19_05_20_06'] + df_less_0['p19_10_21_01'] + df_less_0['p20_05_21_10'] + df_less_0['p21_06_22_01'] + df_less_0['p22_01'] 
    df_less_0 = df_less_0.sort_values(by=['Sum'], ascending=True)
    
    return df_less_0




m_test_100_beta_09_13 = get_minus_results(test_100_beta_09_13)
m_test_100_beta_11_13 = get_minus_results(test_100_beta_11_13)
m_test_100_beta_13_15 = get_minus_results(test_100_beta_13_15)
m_test_100_beta_15_2 = get_minus_results(test_100_beta_15_2)
m_test_100_beta_more_09 = get_minus_results(test_100_beta_more_09)
m_test_100_beta_15 = get_minus_results(test_100_beta_15)
m_test_100_more_beta_2 = get_minus_results(test_100_more_beta_2)
m_test_100_beta_09_2 = get_minus_results(test_100_beta_09_2)

# %%
def get_minus_options(df):
    df_less_150 = df[(df.Sum < -16)]
    return df_less_150['option'].values



minus_test_100_beta_09_13 = get_minus_options(m_test_100_beta_09_13)
minus_test_100_beta_11_13 = get_minus_options(m_test_100_beta_11_13)
minus_test_100_beta_13_15 = get_minus_options(m_test_100_beta_13_15)
minus_test_100_beta_15_2 = get_minus_options(m_test_100_beta_15_2)
minus_test_100_beta_more_09 = get_minus_options(m_test_100_beta_more_09)
minus_test_100_beta_15 = get_minus_options(m_test_100_beta_15)
minus_test_100_more_beta_2 = get_minus_options(m_test_100_more_beta_2)
minus_test_100_beta_09_2 = get_minus_options(m_test_100_beta_09_2)

# %%
minus_test_100_beta_09_2
# Out:
# array(['gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] < 2',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 3',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2.5',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2'],
#       dtype=object)

# %%
m_test_100_beta_09_2
# Out:
#     id        p18_05_20_01         p19_05_20_06         p19_10_21_01         p20_05_21_10         p21_06_22_01               p22_01                                             option                    Sum
# 11  12  -0.829535500911477  -14.920979107093197  -15.691243767161895  -1.0825139064882796   0.6517151943811554                  0.0  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...   -31.8725570872736932
# 12  13   1.140093809914492   -2.605787221660692  -11.442638760010535  0.33612931889191716                  0.0   -5.962888562694611  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  -18.53509141555942884
# 14  15   1.140093993305644  -2.6057890074598564  -11.442642108567371  0.33612596515127746  0.38390351271639134    -5.96288913240644  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  -18.15119677726035460
# ...

# %%
minus_test_100_beta_11_13
# Out:
# array(['gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] < 2',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2.5',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 3',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2'],
#       dtype=object)

# %%
m_test_100_beta_11_13
# Out:
#     id         p18_05_20_01         p19_05_20_06         p19_10_21_01          p20_05_21_10            p21_06_22_01               p22_01                                             option                      Sum
# 11  12  -2.4699124915715878  -14.821873278577224  -15.648680859925774  -0.00242469346810589      1.6262310596576164                  0.0  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...    -31.31666026388507529
# 14  15    1.015111217224953   -3.942481993151237  -11.825723132343708    1.9209155437379433  -0.0030330682100787503   -4.636611207960034  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  -17.4718226407021614503
# 12  13   1.0151102415676678   -3.942484337790916  -11.825717288872694     1.920915550402251                     0.0   -4.636613561208892  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...     -17.4687893959025832
# ...

# %%
minus_test_100_beta_13_15
# Out:
# array(['gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] - 2.5)',
#        'gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] < 2'],
#       dtype=object)

# %%
m_test_100_beta_13_15
# Out:
#     id         p18_05_20_01         p19_05_20_06         p19_10_21_01        p20_05_21_10         p21_06_22_01               p22_01                                             option                    Sum
# 10  11  -14.002756263171623  -17.374701736496977   -8.718618477469343   2.990302242369452   2.7343677545622183   -3.044247209906023  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...   -37.4156536901122957
# 11  12  -1.2502113273775761   -16.35365464943313  -17.657376887235387  -2.511091589970841    1.216388856345121                  0.0  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...   -36.5559455976718131
# 12  13   1.5231992710588884   -1.861929731418203  -11.261766073540988  0.7392264958295459                  0.0  -2.9357273187820017  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...   -13.7969973568527584
# ...

# %%
minus_test_100_beta_15_2
# Out:
# array(['gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] < 2',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 3'],
#       dtype=object)

# %%
m_test_100_beta_15_2
# Out:
#     id        p18_05_20_01         p19_05_20_06         p19_10_21_01         p20_05_21_10         p21_06_22_01               p22_01                                             option                   Sum
# 11  12  0.8895094097495027  -18.507808209319446  -21.336309615171096  -3.0651357848873717  -1.0712071418494051                  0.0  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...  -43.0909513414778161
# 12  13   1.713489791293591  -2.6166733553106254  -14.296258929522951   1.4267182656309416                  0.0   -4.739510832975339  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  -18.5122350608843828
# 14  15  1.7134921527302343   -2.616673616235634  -14.296266532822006   1.4267253413354801    2.541869639262318   -4.739508980656513  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  -15.9703619963861206
# ...

# %%
minus_test_100_beta_more_09
# Out:
# array(['gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] < 2',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 3',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2.5',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2'],
#       dtype=object)

# %%
m_test_100_beta_more_09
# Out:
#     id         p18_05_20_01         p19_05_20_06         p19_10_21_01         p20_05_21_10         p21_06_22_01               p22_01                                             option                    Sum
# 11  12  -1.0800772842658841  -16.280984507848807  -17.072995581614475  -1.8448462260869016    0.673686389111256                  0.0  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...   -35.6052172107048117
# 12  13   1.0495068737850342  -2.9472163270563025  -12.364148238198357   0.3126285717300467                  0.0   -5.818219007248292  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...   -19.7674481269878706
# 14  15   1.0495054359812914   -2.947217801348425  -12.364152795565335   0.3126295630280483   0.5676542486724285    -5.81822032347526  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...   -19.1998016727072518
# ...

# %%
minus_test_100_beta_15
# Out:
# array(['gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] - 2.5)',
#        'gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] < 2',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 3',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2.5',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 3.5'],
#       dtype=object)

# %%
m_test_100_beta_15
# Out:
#     id         p18_05_20_01        p19_05_20_06         p19_10_21_01        p20_05_21_10          p21_06_22_01               p22_01                                             option                    Sum
# 10  11  -21.585796093148172  -35.05083180860038  -25.821985870367502   2.975063978832252     2.851830319840941  -10.663319646902316  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...    -87.295039120345177
# 11  12  -0.8212552456543483  -23.09685659153154   -25.27114155691022  -5.647616440662314  -0.34947272104555926                  0.0  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...  -55.18634255580398156
# 12  13   1.1124379094886199  -4.092232161322984  -17.251783258918522  0.9283164362709871                   0.0  -3.9256207509142693  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...   -23.2288818253961683
# ...

# %%
minus_test_100_more_beta_2
# Out:
# array(['gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] - 2.5)',
#        'gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] < 2',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 3',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2.5',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 3.5'],
#       dtype=object)

# %%
m_test_100_more_beta_2
# Out:
#     id         p18_05_20_01         p19_05_20_06         p19_10_21_01         p20_05_21_10        p21_06_22_01               p22_01                                             option                    Sum
# 10  11   -26.51477828073045  -50.328909143975615   -44.43570890832264  -3.9212337481852524   4.422637127144952   -9.735471660907486  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...  -130.5134646149764914
# 11  12   -3.815107717800534  -31.127677547671478  -32.157105662588116  -10.166951348668679   0.913563014069773                  0.0  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...    -76.353279262659034
# 15  16    -3.01883246239879   -9.753891694122894  -20.366110718551486    2.113928817139038   1.280607266793899   -4.238916985575973  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...    -33.983215776716206
# ...

# %%
minus_test_100_beta_09_2
# Out:
# array(['gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] < 2',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 3',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2.5',
#        'gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i] - 1, 4] + 1.5) and gf_copy.iloc[ind[i], 4] > 1 and gf_copy.iloc[ind[i] - 1, 4] > 2'],
#       dtype=object)

# %%
m_test_100_beta_09_2
# Out:
#     id        p18_05_20_01         p19_05_20_06         p19_10_21_01         p20_05_21_10         p21_06_22_01               p22_01                                             option                    Sum
# 11  12  -0.829535500911477  -14.920979107093197  -15.691243767161895  -1.0825139064882796   0.6517151943811554                  0.0  gf_copy.iloc[ind[i], 4] < (gf_copy.iloc[ind[i]...   -31.8725570872736932
# 12  13   1.140093809914492   -2.605787221660692  -11.442638760010535  0.33612931889191716                  0.0   -5.962888562694611  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  -18.53509141555942884
# 14  15   1.140093993305644  -2.6057890074598564  -11.442642108567371  0.33612596515127746  0.38390351271639134    -5.96288913240644  gf_copy.iloc[ind[i], 4] > (gf_copy.iloc[ind[i]...  -18.15119677726035460
# ...
